# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
#from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

# %%
from tensorflow.keras.optimizers import SGD

# %%
intents_file = open('C:/Users/Nitin/Downloads/intents(v4).json').read()

intents = json.loads(intents_file)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nitin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nitin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Whats', 'up'], 'greeting'), (['hlw'], 'greeting'), (['How', 'are', 'you'], 'ask'), (['how', "'s", 'going', '?'], 'ask'), (['You', 'good', '?'], 'ask'), (['What', 'about', 'you'], 'ask'), (['how', 'do', 'you', 'do', '?'], 'ask'), (['skin', 'specialist'], 'ABC'), (['cardiologist', 'specialist'], 'DEF'), (['dental', 'specialist'], 'JHI'), (['bone', 'specialist'], 'JKL'), (['orthopedics', 'specialist'], 'MNO'), (['can', 'i', 'know', 'the', 'timing', 'of', 'skin', 'specailist', 'doctor'], '123'), (['can', 'i', 'know', 'the', 'timing', 'of', 'cardiologist', 'specailist', 'doctor'], '456'), (['can', 'i', 'know', 'the', 'timing', 'of', 'dental', 'specailist', 'doctor'], '789'), (['can', 'i', 'know', 'the', 'timing', 'of', 'bone', 'specailist', 'doctor'], '987'), (['can', 'i', 'know', 'the', 'timing', 'of', 'orthopedics', 'specailist', 'doctor'], '654'), (['i', 'want', 'to', 'book', 'an', 'appointment', 'for', 'skin', 'specialist'], 'bookings'), (['i', 'want', 'to', 'book', 'an', 'appointment', 'for', 'cardiologist', 'specialist'], 'bookings'), (['i', 'want', 'to', 'book', 'an', 'appointment', 'for', 'dental', 'specialist'], 'bookings'), (['i', 'want', 'to', 'book', 'an', 'appointment', 'for', 'bone', 'specialist'], 'bookings'), (['i', 'want', 'to', 'book', 'an', 'appointment', 'for', 'orthopedic', 'specialist'], 'bookings'), (['name-nithin', 'suvarna'], 'personal information for skin specailist booking'), (['phone', 'no-97565754665'], 'personal information for skin specailist booking'), (['address-mira', 'road', 'near', 'shiv', 'garden', 'puspha', 'apartment', 'flat', 'no', '102'], 'personal information for skin specailist booking'), (['name-mihir', 'waghela'], 'personal information for cardiologist specailist booking'), (['phone', 'no-56475667776'], 'personal information for cardiologist specailist booking'), (['address-borivali', 'west', 'near', 'lic', 'colony', 'shram', 'safalya', 'flat', 'no', '11'], 'personal information for cardiologist specailist booking'), (['name-rayyan', 'bawani'], 'personal information for dental specailist booking'), (['phone', 'no-9756575466567'], 'personal information for dental specailist booking'), (['address-kandivali', 'east', 'near', 'sai', 'baba', 'mandhir', 'mauli', 'omkar', 'apartment', 'flat', 'no', '110'], 'personal information for dental specailist booking'), (['name-omkar', 'tiwari'], 'personal information for bone specailist booking'), (['phone', 'no-97690374723'], 'personal information for bone specailist booking'), (['address-malad', 'west', 'near', 'sagar', 'height', 'shiv', 'sai', 'apartment', 'flat', 'no', '1105'], 'personal information for bone specailist booking'), (['name-viraj', 'kadam'], 'personal information for orthopedic specailist booking'), (['phone', 'no-34568788765'], 'personal information for orthopedic specailist booking'), (['address-malad', 'east', 'near', 'triveni', 'nagar', 'mauli', 'omkar', 'apartment', 'flat', 'no', '1105'], 'personal information for orthopedic specailist booking'), (['when', 'i', 'get', 'message', 'of', 'booking', 'for', 'skin', 'specailist'], 'confirm1'), (['when', 'i', 'get', 'message', 'of', 'booking', 'for', 'cardiologist', 'specailist'], 'confirm2'), (['when', 'i', 'get', 'message', 'of', 'booking', 'for', 'dental', 'specailist'], 'confirm3'), (['when', 'i', 'get', 'message', 'of', 'booking', 'for', 'bone', 'specailist'], 'confirm4'), (['when', 'i', 'get', 'message', 'of', 'booking', 'for', 'orthopedic', 'specailist'], 'confirm5'), (['No', 'thanks', 'for', 'the', 'help'], 'Anything_Else'), (['Thanks', 'for', 'the', 'help'], 'Anything_Else'), (['No', 'All', 'Perfect'], 'Anything_Else'), (['Thats', 'all'], 'Anything_Else'), (['cya'], 'goodbye'), (['bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['I', 'am', 'Leaving'], 'goodbye'), (['Have', 'a', 'Good', 'day'], 'goodbye')]

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 56 documents
# 25 classes ['123', '456', '654', '789', '987', 'ABC', 'Anything_Else', 'DEF', 'JHI', 'JKL', 'MNO', 'ask', 'bookings', 'confirm1', 'confirm2', 'confirm3', 'confirm4', 'confirm5', 'goodbye', 'greeting', 'personal information for bone specailist booking', 'personal information for cardiologist specailist booking', 'personal information for dental specailist booking', 'personal information for orthopedic specailist booking', 'personal information for skin specailist booking']
# 104 unique lemmatized words ["'s", '102', '11', '110', '1105', 'a', 'about', 'address-borivali', 'address-kandivali', 'address-malad', 'address-mira', 'all', 'am', 'an', 'anyone', 'apartment', 'appointment', 'are', 'baba', 'bawani', 'bone', 'book', 'booking', 'bye', 'can', 'cardiologist', 'colony', 'cya', 'day', 'dental', 'do', 'doctor', 'east', 'flat', 'for', 'garden', 'get', 'going', 'good', 'goodbye', 'have', 'height', 'hello', 'help', 'hi', 'hlw', 'how', 'i', 'is', 'kadam', 'know', 'later', 'leaving', 'lic', 'mandhir', 'mauli', 'message', 'nagar', 'name-mihir', 'name-nithin', 'name-omkar', 'name-rayyan', 'name-viraj', 'near', 'no', 'no-34568788765', 'no-56475667776', 'no-97565754665', 'no-9756575466567', 'no-97690374723', 'of', 'omkar', 'orthopedic', 'orthopedics', 'perfect', 'phone', 'puspha', 'road', 'safalya', 'sagar', 'sai', 'see', 'shiv', 'shram', 'skin', 'specailist', 'specialist', 'suvarna', 'thanks', 'thats', 'the', 'there', 'timing', 'tiwari', 'to', 'triveni', 'up', 'waghela', 'want', 'west', 'what', 'whats', 'when', 'you']

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created
# C:\Users\Nitin\AppData\Local\Temp/ipykernel_12864/414232894.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# C:\Users\Nitin\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 12/12 [==============================] - 1s 3ms/step - loss: 3.2457 - accuracy: 0.0357
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1694 - accuracy: 0.0536
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0367 - accuracy: 0.2143
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9389 - accuracy: 0.2500
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7366 - accuracy: 0.1964
# Epoch 6/200
# 12/12 [==============================] - 0s 1ms/step - loss: 2.6291 - accuracy: 0.2321
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4747 - accuracy: 0.2857
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4701 - accuracy: 0.3571
# Epoch 9/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4625 - accuracy: 0.3214
# Epoch 10/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3713 - accuracy: 0.3393
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2235 - accuracy: 0.3393
# Epoch 12/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1974 - accuracy: 0.3214
# Epoch 13/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0538 - accuracy: 0.3571
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0826 - accuracy: 0.3750
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9147 - accuracy: 0.3750
# Epoch 16/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8801 - accuracy: 0.4464
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6505 - accuracy: 0.4821
# Epoch 18/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6159 - accuracy: 0.5536
# Epoch 19/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5947 - accuracy: 0.5179
# Epoch 20/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5344 - accuracy: 0.5357
# Epoch 21/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4351 - accuracy: 0.5714
# Epoch 22/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5296 - accuracy: 0.5714
# Epoch 23/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4591 - accuracy: 0.5357
# Epoch 24/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6071 - accuracy: 0.4821
# Epoch 25/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2435 - accuracy: 0.6607
# Epoch 26/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1721 - accuracy: 0.6607
# Epoch 27/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1210 - accuracy: 0.6607
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0781 - accuracy: 0.6786
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1899 - accuracy: 0.6607
# Epoch 30/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0442 - accuracy: 0.6250
# Epoch 31/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1212 - accuracy: 0.7143
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8683 - accuracy: 0.7500
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0770 - accuracy: 0.6964
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9648 - accuracy: 0.6964
# Epoch 35/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1266 - accuracy: 0.6429
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8262 - accuracy: 0.7679
# Epoch 37/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9620 - accuracy: 0.6786
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8461 - accuracy: 0.7321
# Epoch 39/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8876 - accuracy: 0.7321
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9119 - accuracy: 0.7857
# Epoch 41/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7440 - accuracy: 0.7500
# Epoch 42/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7090 - accuracy: 0.7679
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8231 - accuracy: 0.7500
# Epoch 44/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8144 - accuracy: 0.6607
# Epoch 45/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.8036
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6622 - accuracy: 0.7679
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8041 - accuracy: 0.7143
# Epoch 48/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7282 - accuracy: 0.7500
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.7857
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6260 - accuracy: 0.7857
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6652 - accuracy: 0.8036
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.7321
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.8393
# Epoch 54/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6331 - accuracy: 0.8214
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.8750
# Epoch 56/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.7857
# Epoch 57/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6593 - accuracy: 0.8214
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5791 - accuracy: 0.8214
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4803 - accuracy: 0.8393
# Epoch 60/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4925 - accuracy: 0.8393
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5480 - accuracy: 0.8214
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4341 - accuracy: 0.9107
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.8571
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5974 - accuracy: 0.7857
# Epoch 65/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.8393
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5178 - accuracy: 0.8214
# Epoch 67/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6678 - accuracy: 0.7857
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5276 - accuracy: 0.8571
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.7857
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.8214
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8571
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7857
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.8571
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3819 - accuracy: 0.8750
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.8750
# Epoch 76/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8036
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.8214
# Epoch 78/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4636 - accuracy: 0.8929
# Epoch 79/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8750
# Epoch 80/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3102 - accuracy: 0.9286
# Epoch 81/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8571
# Epoch 82/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.9107
# Epoch 83/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.8393
# Epoch 84/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8214
# Epoch 85/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4275 - accuracy: 0.8036
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4833 - accuracy: 0.8393
# Epoch 87/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8393
# Epoch 88/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.8393
# Epoch 89/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8929
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8750
# Epoch 91/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4662 - accuracy: 0.8571
# Epoch 92/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5376 - accuracy: 0.8393
# Epoch 93/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8393
# Epoch 94/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8929
# Epoch 95/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.8393
# Epoch 96/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8929
# Epoch 97/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4634 - accuracy: 0.8929
# Epoch 98/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6109 - accuracy: 0.7857
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5403 - accuracy: 0.8214
# Epoch 100/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.9107
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8750
# Epoch 102/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4085 - accuracy: 0.8571
# Epoch 103/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2126 - accuracy: 0.9643
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2783 - accuracy: 0.9286
# Epoch 105/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.8571
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.8393
# Epoch 107/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2889 - accuracy: 0.8750
# Epoch 108/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.9286
# Epoch 109/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.8571
# Epoch 110/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8571
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2875 - accuracy: 0.9107
# Epoch 112/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.9464
# Epoch 113/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8929
# Epoch 114/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2956 - accuracy: 0.8750
# Epoch 115/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9107
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8393
# Epoch 117/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8393
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3437 - accuracy: 0.8571
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3178 - accuracy: 0.8929
# Epoch 120/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8929
# Epoch 121/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.8750
# Epoch 122/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2209 - accuracy: 0.9464
# Epoch 123/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9286
# Epoch 124/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.9107
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.9107
# Epoch 126/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.8750
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.9107
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.8929
# Epoch 129/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8571
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9286
# Epoch 131/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8929
# Epoch 132/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.9286
# Epoch 133/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.9464
# Epoch 134/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1778 - accuracy: 0.9821
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1881 - accuracy: 0.9286
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1533 - accuracy: 0.9464
# Epoch 137/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.9107
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 0.9286
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9286
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1538 - accuracy: 0.9821
# Epoch 141/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.9464
# Epoch 142/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2123 - accuracy: 0.9464
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1855 - accuracy: 0.9286
# Epoch 144/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.9464
# Epoch 145/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1531 - accuracy: 0.9286
# Epoch 146/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9107
# Epoch 147/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 148/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9643
# Epoch 149/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9464
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2966 - accuracy: 0.8750
# Epoch 151/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2165 - accuracy: 0.9107
# Epoch 152/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8571
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1854 - accuracy: 0.9464
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9107
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.9286
# Epoch 156/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8750
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9821
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2970 - accuracy: 0.8571
# Epoch 159/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9643
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9821
# Epoch 161/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.9464
# Epoch 162/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2009 - accuracy: 0.9286
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 0.9643
# Epoch 164/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2710 - accuracy: 0.9286
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.9643
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 0.9464
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.8929
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.9464
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1789 - accuracy: 0.9286
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.9107
# Epoch 171/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2170 - accuracy: 0.9286
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9286
# Epoch 173/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3939 - accuracy: 0.8929
# Epoch 174/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.8929
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1451 - accuracy: 0.9821
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1352 - accuracy: 0.9821
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2034 - accuracy: 0.9643
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.9464
# Epoch 179/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2187 - accuracy: 0.9464
# Epoch 180/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2702 - accuracy: 0.8929
# Epoch 181/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1696 - accuracy: 0.9464
# Epoch 182/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9821
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9643
# Epoch 184/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9286
# Epoch 185/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9821
# Epoch 186/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9464
# Epoch 187/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2029 - accuracy: 0.9286
# Epoch 188/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1642 - accuracy: 0.9643
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 1.0000
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9286
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9464
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9643
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9821
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9821
# Epoch 195/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9821
# Epoch 196/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1494 - accuracy: 0.9643
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1811 - accuracy: 0.9464
# Epoch 198/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9464
# Epoch 199/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9821
# Epoch 200/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 1.0000
# model is created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('C:/Users/Nitin/Downloads/intents(v4).json').read())

words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 ))
        ints = predict_class(msg)
        res = getResponse(ints, intents)
        ChatBox.insert(END, "Bot: " + res + '\n\n')
        ChatBox.config(state=DISABLED)
        ChatBox.yview(END)
root = Tk()
root.title("Chatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)
# Out:
# ''

# %%
#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatBox.config(state=DISABLED)

# %%
#Bind scrollbar to Chat window
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set

# %%
#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )

# %%
#Create the box to enter message
EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")

# %%
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
root.mainloop()
